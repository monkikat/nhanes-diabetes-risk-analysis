# %% [markdown]
# # Libraries and Imports

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Loading NHASES Datasets

# %%
# DEMOGRAPHIC DATA
demo = pd.read_sas("./data/DEMO_L.xpt", format="xport")

# %%
# EXAMINATION DATA
bmx = pd.read_sas("./data/BMX_L.xpt", format="xport")
bpxo = pd.read_sas("./data/BPXO_L.xpt", format="xport")

# %%
# LABORATORY DATA
ghb = pd.read_sas("./data/GHB_L.xpt", format="xport")
glu = pd.read_sas("./data/GLU_L.xpt", format="xport")

# %%
# QUESTIONNAIRE DATA
paq = pd.read_sas("./data/PAQ_L.xpt", format="xport")
smq = pd.read_sas("./data/SMQ_L.xpt", format="xport")
bpq = pd.read_sas("./data/BPQ_L.xpt", format="xport")
diq = pd.read_sas("./data/DIQ_L.xpt", format="xport")

# %% [markdown]
# # Retaining Required Columns

# %% [markdown]
# ## Demographic Data

# %%
demo.columns

# %%
demo_req_columns = demo[[
    'SEQN', 'RIDAGEYR', 'RIAGENDR', 
    'RIDRETH3', 'DMDEDUC2', 'INDFMPIR', 
    'RIDEXPRG', 'WTMEC2YR', 'SDMVSTRA', 
    'SDMVPSU'
    ]]

demo_req_columns.columns

# %% [markdown]
# ## Examination Data

# %% [markdown]
# ## Laboratory Data

# %% [markdown]
# ## Questionnaire Data
